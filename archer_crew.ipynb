# %%
from crewai import Agent, Task, Crew
from crewai_tools import Tool
import json
import sqlite3
from typing import Dict, Any
import os

#########################
# Setup Data and Paths
#########################

BASE_DIR = "./database/"
db_map = {}

for db_id in os.listdir(BASE_DIR):
    db_dir_path = os.path.join(BASE_DIR, db_id)
    if os.path.isdir(db_dir_path):
        # Try to find a .sqlite file or .db file that matches the db_id
        sqlite_path = os.path.join(db_dir_path, f"{db_id}.sqlite")
        db_path = os.path.join(db_dir_path, f"{db_id}.db")

        if os.path.exists(sqlite_path):
            db_map[db_id] = sqlite_path
        elif os.path.exists(db_path):
            db_map[db_id] = db_path
        else:
            # If neither file is found, you can skip or handle error
            print(f"No .sqlite or .db file found for {db_id}, skipping...")
            
# Assume we have a JSON schema file for the database(s).
schema_path = "./schema_info.json"
with open(schema_path, 'r') as f:
    schema_info = json.load(f)

# %%
class SchemaInfoTool(Tool):
    def __init__(self):
        super().__init__(
            name="schema_info_tool",
            description="Return the schema_info for a given db_id, along with question and reasoning_type.",
            func=self.run
        )

    def run(self, question: str, db_id: str, reasoning_type: str) -> Dict[str, Any]:
        db_schema = schema_info.get(db_id, {})
        return {
            "schema_info": db_schema,
            "db_id": db_id,
            "reasoning_type": reasoning_type,
            "question": question
        }

# %%
class SQLExecutionTool(Tool):
    def __init__(self):
        super().__init__(
            name="sql_execution_tool",
            description="Execute the provided SQL query on the specified db_id and return the results.",
            func=self.run
        )

    def run(self, sql_query: str, db_id: str) -> Dict[str, Any]:
        if db_id not in db_map:
            return {"error": f"No database found for db_id={db_id}", "sql_query": sql_query, "db_id": db_id}

        db_path = db_map[db_id]
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        results = []
        columns = []
        try:
            cursor.execute(sql_query)
            results = cursor.fetchall()
            columns = [desc[0] for desc in cursor.description] if cursor.description else []
        except Exception as e:
            print(f"Error executing query: {e}")
        finally:
            conn.close()

        return {
            "columns": columns,
            "rows": results,
            "db_id": db_id,
            "sql_query": sql_query
        }

# %%
#########################
# Define Agents
#########################


# 1. Knowledge Agent
knowledge_agent = Agent(
    name="knowledge_agent",
    role="System",
    goal="Provide schema information and other database knowledge.",
    backstory="This agent holds database schema details.",
    tools=[SchemaInfoTool()],
    llm="gpt-4o-mini"  # or None if no LLM
)

# The description will instruct the agent to use the schema_info_tool.
knowledge_task = Task(
    description=(
        "You are a system agent. The user provides a question, db_id, and reasoning_type. "
        "Use the schema_info_tool to retrieve the schema information for the given db_id."
    ),
    expected_output="Schema info and context",
    agent=knowledge_agent,
    parameters={
        "question": "{question}",
        "db_id": "{db_id}",
        "reasoning_type": "{reasoning_type}"
    }
)

# %%
# 2. Schema Linking Agent: Identifies relevant tables/columns.
schema_linking_agent = Agent(
    name="schema_linking_agent",
    role="System",
    goal="Link user query to database schema elements.",
    backstory="This agent uses the schema info to find relevant tables/columns."
)

schema_linking_task = Task(
    description=(
        "Given the schema_info and the user question, identify relevant tables and columns. "
        "Return linked_tables and linked_columns as JSON."
    ),
    expected_output="Linked schema elements",
    agent=schema_linking_agent,
    parameters={
        "schema_info": knowledge_task,
        "question": "{question}",
        "db_id": "{db_id}",
        "reasoning_type": "{reasoning_type}"
    }
)

# %%
# 3. SQL Generation Agent
sql_generation_agent = Agent(
    name="sql_generation_agent",
    role="System",
    goal="Generate a correct SQL query from the question and schema links.",
    backstory="This agent uses reasoning to produce an SQL query.",
    llm="gpt-4o-mini"
)

sql_generation_task = Task(
    description=(
        "Given the linked_tables and linked_columns, and the question, generate a valid SQL query."
    ),
    expected_output="SQL query string",
    agent=sql_generation_agent,
    parameters={
        "linked_tables": schema_linking_task,
        "linked_columns": schema_linking_task,
        "question": "{question}",
        "db_id": "{db_id}",
        "reasoning_type": "{reasoning_type}"
    }
)

# %%
# 4. SQL Execution Agent
sql_execution_agent = Agent(
    name="sql_execution_agent",
    role="System",
    goal="Execute the SQL query and return the results.",
    backstory="This agent runs the SQL against the specified database.",
    tools=[SQLExecutionTool()]
)

sql_execution_task = Task(
    description=(
        "Use the sql_execution_tool to run the given SQL query on db_id and return the results."
    ),
    expected_output="Query results",
    agent=sql_execution_agent,
    parameters={
        "sql_query": sql_generation_task,
        "db_id": "{db_id}",
        "reasoning_type": "{reasoning_type}",
        "question": "{question}"
    }
)

# %%
#########################
# Create Crew and Run
#########################

crew = Crew(
    agents=[
        knowledge_agent,
        schema_linking_agent,
        sql_generation_agent,
        sql_execution_agent
    ],
    tasks=[
        knowledge_task,
        schema_linking_task,
        sql_generation_task,
        sql_execution_task
    ]
)

# Example usage:
db_id = "concert_singer"
reasoning_type = "- + C"
question = 'List the name and age of each singer at the time of the release of the song "Gentleman".'

result = crew.kickoff(
    inputs={
        "question": question,
        "db_id": db_id,
        "reasoning_type": reasoning_type
    }
)


print("---------------------------------------------------")
print("Final Result:")
print(result)
# Out:
# 2024-12-19 06:35:14,554 - 140634424218048 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# 2024-12-19 06:35:14,592 - 140634424218048 - llm.py-llm:170 - ERROR: LiteLLM call failed: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2024-12-19 06:35:14,598 - 140634424218048 - llm.py-llm:170 - ERROR: LiteLLM call failed: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# 2024-12-19 06:35:14,602 - 140634424218048 - llm.py-llm:170 - ERROR: LiteLLM call failed: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
#
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
#
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:609, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     608             else:
# --> 609                 raise e
#     610 except OpenAIError as e:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:522, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     518     raise OpenAIError(
#     519         status_code=422, message="max retries must be an int"
#     520     )
# --> 522 openai_client: OpenAI = self._get_openai_client(  # type: ignore
#     523     is_async=False,
#     524     api_key=api_key,
#     525     api_base=api_base,
#     526     timeout=timeout,
#     527     max_retries=max_retries,
#     528     organization=organization,
#     529     client=client,
#     530 )
#     532 ## LOGGING
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:333, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, timeout, max_retries, organization, client)
#     332 else:
# --> 333     _new_client = OpenAI(
#     334         api_key=api_key,
#     335         base_url=api_base,
#     336         http_client=litellm.client_session,
#     337         timeout=timeout,
#     338         max_retries=max_retries,
#     339         organization=organization,
#     340     )
#     342 ## SAVE CACHE KEY
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/openai/_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:1595, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1589     logging.post_call(
#    1590         input=messages,
#    1591         api_key=api_key,
#    1592         original_response=str(e),
#    1593         additional_args={"headers": headers},
#    1594     )
# -> 1595     raise e
#    1597 if optional_params.get("stream", False):
#    1598     ## LOGGING
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:1568, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1567 try:
# -> 1568     response = openai_chat_completions.completion(
#    1569         model=model,
#    1570         messages=messages,
#    1571         headers=headers,
#    1572         model_response=model_response,
#    1573         print_verbose=print_verbose,
#    1574         api_key=api_key,
#    1575         api_base=api_base,
#    1576         acompletion=acompletion,
#    1577         logging_obj=logging,
#    1578         optional_params=optional_params,
#    1579         litellm_params=litellm_params,
#    1580         logger_fn=logger_fn,
#    1581         timeout=timeout,  # type: ignore
#    1582         custom_prompt_dict=custom_prompt_dict,
#    1583         client=client,  # pass AsyncOpenAI, OpenAI client
#    1584         organization=organization,
#    1585         custom_llm_provider=custom_llm_provider,
#    1586     )
#    1587 except Exception as e:
#    1588     ## LOGGING - log the original exception returned
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:619, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     618     error_headers = getattr(error_response, "headers", None)
# --> 619 raise OpenAIError(
#     620     status_code=status_code, message=error_text, headers=error_headers
#     621 )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agent.py:345, in Agent.execute_task(self, task, context, tools)
#     344 try:
# --> 345     result = self.agent_executor.invoke(
#     346         {
#     347             "input": task_prompt,
#     348             "tool_names": self.agent_executor.tools_names,
#     349             "tools": self.agent_executor.tools_description,
#     350             "ask_for_human_input": task.human_input,
#     351         }
#     352     )["output"]
#     353 except Exception as e:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:102, in CrewAgentExecutor.invoke(self, inputs)
#     101 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
# --> 102 formatted_answer = self._invoke_loop()
#     104 if self.ask_for_human_input:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:193, in CrewAgentExecutor._invoke_loop(self, formatted_answer)
#     192     else:
# --> 193         raise e
#     195 self._show_logs(formatted_answer)
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:115, in CrewAgentExecutor._invoke_loop(self, formatted_answer)
#     114 if not self.request_within_rpm_limit or self.request_within_rpm_limit():
# --> 115     answer = self.llm.call(
#     116         self.messages,
#     117         callbacks=self.callbacks,
#     118     )
#     120     if answer is None or answer == "":
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/llm.py:164, in LLM.call(self, messages, callbacks)
#     162 params = {k: v for k, v in params.items() if v is not None}
# --> 164 response = litellm.completion(**params)
#     165 return response["choices"][0]["message"]["content"]
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/utils.py:999, in client.<locals>.wrapper(*args, **kwargs)
#     996     logging_obj.failure_handler(
#     997         e, traceback_exception, start_time, end_time
#     998     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# --> 999 raise e
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/utils.py:880, in client.<locals>.wrapper(*args, **kwargs)
#     879 # MODEL CALL
# --> 880 result = original_function(*args, **kwargs)
#     881 end_time = datetime.datetime.now()
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:2951, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    2949 except Exception as e:
#    2950     ## Map to OpenAI Exception
# -> 2951     raise exception_type(
#    2952         model=model,
#    2953         custom_llm_provider=custom_llm_provider,
#    2954         original_exception=e,
#    2955         completion_kwargs=args,
#    2956         extra_kwargs=kwargs,
#    2957     )
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2148, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2147     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2148     raise e
#    2149 else:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:314, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     313     exception_mapping_worked = True
# --> 314     raise AuthenticationError(
#     315         message=f"AuthenticationError: {exception_provider} - {message}",
#     316         llm_provider=custom_llm_provider,
#     317         model=model,
#     318         response=getattr(original_exception, "response", None),
#     319         litellm_debug_info=extra_information,
#     320     )
#     321 elif "Mistral API raised a streaming error" in error_str:
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:609, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     608             else:
# --> 609                 raise e
#     610 except OpenAIError as e:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:522, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     518     raise OpenAIError(
#     519         status_code=422, message="max retries must be an int"
#     520     )
# --> 522 openai_client: OpenAI = self._get_openai_client(  # type: ignore
#     523     is_async=False,
#     524     api_key=api_key,
#     525     api_base=api_base,
#     526     timeout=timeout,
#     527     max_retries=max_retries,
#     528     organization=organization,
#     529     client=client,
#     530 )
#     532 ## LOGGING
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:333, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, timeout, max_retries, organization, client)
#     332 else:
# --> 333     _new_client = OpenAI(
#     334         api_key=api_key,
#     335         base_url=api_base,
#     336         http_client=litellm.client_session,
#     337         timeout=timeout,
#     338         max_retries=max_retries,
#     339         organization=organization,
#     340     )
#     342 ## SAVE CACHE KEY
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/openai/_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:1595, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1589     logging.post_call(
#    1590         input=messages,
#    1591         api_key=api_key,
#    1592         original_response=str(e),
#    1593         additional_args={"headers": headers},
#    1594     )
# -> 1595     raise e
#    1597 if optional_params.get("stream", False):
#    1598     ## LOGGING
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:1568, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1567 try:
# -> 1568     response = openai_chat_completions.completion(
#    1569         model=model,
#    1570         messages=messages,
#    1571         headers=headers,
#    1572         model_response=model_response,
#    1573         print_verbose=print_verbose,
#    1574         api_key=api_key,
#    1575         api_base=api_base,
#    1576         acompletion=acompletion,
#    1577         logging_obj=logging,
#    1578         optional_params=optional_params,
#    1579         litellm_params=litellm_params,
#    1580         logger_fn=logger_fn,
#    1581         timeout=timeout,  # type: ignore
#    1582         custom_prompt_dict=custom_prompt_dict,
#    1583         client=client,  # pass AsyncOpenAI, OpenAI client
#    1584         organization=organization,
#    1585         custom_llm_provider=custom_llm_provider,
#    1586     )
#    1587 except Exception as e:
#    1588     ## LOGGING - log the original exception returned
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:619, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     618     error_headers = getattr(error_response, "headers", None)
# --> 619 raise OpenAIError(
#     620     status_code=status_code, message=error_text, headers=error_headers
#     621 )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agent.py:345, in Agent.execute_task(self, task, context, tools)
#     344 try:
# --> 345     result = self.agent_executor.invoke(
#     346         {
#     347             "input": task_prompt,
#     348             "tool_names": self.agent_executor.tools_names,
#     349             "tools": self.agent_executor.tools_description,
#     350             "ask_for_human_input": task.human_input,
#     351         }
#     352     )["output"]
#     353 except Exception as e:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:102, in CrewAgentExecutor.invoke(self, inputs)
#     101 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
# --> 102 formatted_answer = self._invoke_loop()
#     104 if self.ask_for_human_input:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:193, in CrewAgentExecutor._invoke_loop(self, formatted_answer)
#     192     else:
# --> 193         raise e
#     195 self._show_logs(formatted_answer)
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:115, in CrewAgentExecutor._invoke_loop(self, formatted_answer)
#     114 if not self.request_within_rpm_limit or self.request_within_rpm_limit():
# --> 115     answer = self.llm.call(
#     116         self.messages,
#     117         callbacks=self.callbacks,
#     118     )
#     120     if answer is None or answer == "":
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/llm.py:164, in LLM.call(self, messages, callbacks)
#     162 params = {k: v for k, v in params.items() if v is not None}
# --> 164 response = litellm.completion(**params)
#     165 return response["choices"][0]["message"]["content"]
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/utils.py:999, in client.<locals>.wrapper(*args, **kwargs)
#     996     logging_obj.failure_handler(
#     997         e, traceback_exception, start_time, end_time
#     998     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# --> 999 raise e
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/utils.py:880, in client.<locals>.wrapper(*args, **kwargs)
#     879 # MODEL CALL
# --> 880 result = original_function(*args, **kwargs)
#     881 end_time = datetime.datetime.now()
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:2951, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    2949 except Exception as e:
#    2950     ## Map to OpenAI Exception
# -> 2951     raise exception_type(
#    2952         model=model,
#    2953         custom_llm_provider=custom_llm_provider,
#    2954         original_exception=e,
#    2955         completion_kwargs=args,
#    2956         extra_kwargs=kwargs,
#    2957     )
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2148, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2147     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2148     raise e
#    2149 else:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:314, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     313     exception_mapping_worked = True
# --> 314     raise AuthenticationError(
#     315         message=f"AuthenticationError: {exception_provider} - {message}",
#     316         llm_provider=custom_llm_provider,
#     317         model=model,
#     318         response=getattr(original_exception, "response", None),
#     319         litellm_debug_info=extra_information,
#     320     )
#     321 elif "Mistral API raised a streaming error" in error_str:
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:609, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     608             else:
# --> 609                 raise e
#     610 except OpenAIError as e:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:522, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     518     raise OpenAIError(
#     519         status_code=422, message="max retries must be an int"
#     520     )
# --> 522 openai_client: OpenAI = self._get_openai_client(  # type: ignore
#     523     is_async=False,
#     524     api_key=api_key,
#     525     api_base=api_base,
#     526     timeout=timeout,
#     527     max_retries=max_retries,
#     528     organization=organization,
#     529     client=client,
#     530 )
#     532 ## LOGGING
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:333, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, timeout, max_retries, organization, client)
#     332 else:
# --> 333     _new_client = OpenAI(
#     334         api_key=api_key,
#     335         base_url=api_base,
#     336         http_client=litellm.client_session,
#     337         timeout=timeout,
#     338         max_retries=max_retries,
#     339         organization=organization,
#     340     )
#     342 ## SAVE CACHE KEY
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/openai/_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:1595, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1589     logging.post_call(
#    1590         input=messages,
#    1591         api_key=api_key,
#    1592         original_response=str(e),
#    1593         additional_args={"headers": headers},
#    1594     )
# -> 1595     raise e
#    1597 if optional_params.get("stream", False):
#    1598     ## LOGGING
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:1568, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1567 try:
# -> 1568     response = openai_chat_completions.completion(
#    1569         model=model,
#    1570         messages=messages,
#    1571         headers=headers,
#    1572         model_response=model_response,
#    1573         print_verbose=print_verbose,
#    1574         api_key=api_key,
#    1575         api_base=api_base,
#    1576         acompletion=acompletion,
#    1577         logging_obj=logging,
#    1578         optional_params=optional_params,
#    1579         litellm_params=litellm_params,
#    1580         logger_fn=logger_fn,
#    1581         timeout=timeout,  # type: ignore
#    1582         custom_prompt_dict=custom_prompt_dict,
#    1583         client=client,  # pass AsyncOpenAI, OpenAI client
#    1584         organization=organization,
#    1585         custom_llm_provider=custom_llm_provider,
#    1586     )
#    1587 except Exception as e:
#    1588     ## LOGGING - log the original exception returned
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/llms/openai/openai.py:619, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     618     error_headers = getattr(error_response, "headers", None)
# --> 619 raise OpenAIError(
#     620     status_code=status_code, message=error_text, headers=error_headers
#     621 )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[37], line 25
#      22 reasoning_type = "- + C"
#      23 question = 'List the name and age of each singer at the time of the release of the song "Gentleman".'
# ---> 25 result = crew.kickoff(
#      26     inputs={
#      27         "question": question,
#      28         "db_id": db_id,
#      29         "reasoning_type": reasoning_type
#      30     }
#      31 )
#      34 print("---------------------------------------------------")
#      35 print("Final Result:")
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/crew.py:553, in Crew.kickoff(self, inputs)
#     550 metrics: List[UsageMetrics] = []
#     552 if self.process == Process.sequential:
# --> 553     result = self._run_sequential_process()
#     554 elif self.process == Process.hierarchical:
#     555     result = self._run_hierarchical_process()
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/crew.py:660, in Crew._run_sequential_process(self)
#     658 def _run_sequential_process(self) -> CrewOutput:
#     659     """Executes tasks sequentially and returns the final output."""
# --> 660     return self._execute_tasks(self.tasks)
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/crew.py:758, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     755     futures.clear()
#     757 context = self._get_context(task, task_outputs)
# --> 758 task_output = task.execute_sync(
#     759     agent=agent_to_use,
#     760     context=context,
#     761     tools=agent_to_use.tools,
#     762 )
#     763 task_outputs = [task_output]
#     764 self._process_task_result(task, task_output)
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/task.py:192, in Task.execute_sync(self, agent, context, tools)
#     185 def execute_sync(
#     186     self,
#     187     agent: Optional[BaseAgent] = None,
#     188     context: Optional[str] = None,
#     189     tools: Optional[List[BaseTool]] = None,
#     190 ) -> TaskOutput:
#     191     """Execute the task synchronously."""
# --> 192     return self._execute_core(agent, context, tools)
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/task.py:250, in Task._execute_core(self, agent, context, tools)
#     246 tools = tools or self.tools or []
#     248 self.processed_by_agents.add(agent.role)
# --> 250 result = agent.execute_task(
#     251     task=self,
#     252     context=context,
#     253     tools=tools,
#     254 )
#     256 pydantic_output, json_output = self._export_output(result)
#     258 task_output = TaskOutput(
#     259     name=self.name,
#     260     description=self.description,
#    (...)
#     266     output_format=self._get_output_format(),
#     267 )
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agent.py:357, in Agent.execute_task(self, task, context, tools)
#     355     if self._times_executed > self.max_retry_limit:
#     356         raise e
# --> 357     result = self.execute_task(task, context, tools)
#     359 if self.max_rpm and self._rpm_controller:
#     360     self._rpm_controller.stop_rpm_counter()
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agent.py:357, in Agent.execute_task(self, task, context, tools)
#     355     if self._times_executed > self.max_retry_limit:
#     356         raise e
# --> 357     result = self.execute_task(task, context, tools)
#     359 if self.max_rpm and self._rpm_controller:
#     360     self._rpm_controller.stop_rpm_counter()
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agent.py:356, in Agent.execute_task(self, task, context, tools)
#     354     self._times_executed += 1
#     355     if self._times_executed > self.max_retry_limit:
# --> 356         raise e
#     357     result = self.execute_task(task, context, tools)
#     359 if self.max_rpm and self._rpm_controller:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agent.py:345, in Agent.execute_task(self, task, context, tools)
#     342     task_prompt = self._use_trained_data(task_prompt=task_prompt)
#     344 try:
# --> 345     result = self.agent_executor.invoke(
#     346         {
#     347             "input": task_prompt,
#     348             "tool_names": self.agent_executor.tools_names,
#     349             "tools": self.agent_executor.tools_description,
#     350             "ask_for_human_input": task.human_input,
#     351         }
#     352     )["output"]
#     353 except Exception as e:
#     354     self._times_executed += 1
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:102, in CrewAgentExecutor.invoke(self, inputs)
#      99 self._show_start_logs()
#     101 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
# --> 102 formatted_answer = self._invoke_loop()
#     104 if self.ask_for_human_input:
#     105     formatted_answer = self._handle_human_feedback(formatted_answer)
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:193, in CrewAgentExecutor._invoke_loop(self, formatted_answer)
#     191         return self._invoke_loop(formatted_answer)
#     192     else:
# --> 193         raise e
#     195 self._show_logs(formatted_answer)
#     196 return formatted_answer
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:115, in CrewAgentExecutor._invoke_loop(self, formatted_answer)
#     113 while not isinstance(formatted_answer, AgentFinish):
#     114     if not self.request_within_rpm_limit or self.request_within_rpm_limit():
# --> 115         answer = self.llm.call(
#     116             self.messages,
#     117             callbacks=self.callbacks,
#     118         )
#     120         if answer is None or answer == "":
#     121             self._printer.print(
#     122                 content="Received None or empty response from LLM call.",
#     123                 color="red",
#     124             )
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/crewai/llm.py:164, in LLM.call(self, messages, callbacks)
#     161     # Remove None values to avoid passing unnecessary parameters
#     162     params = {k: v for k, v in params.items() if v is not None}
# --> 164     response = litellm.completion(**params)
#     165     return response["choices"][0]["message"]["content"]
#     166 except Exception as e:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/utils.py:999, in client.<locals>.wrapper(*args, **kwargs)
#     995 if logging_obj:
#     996     logging_obj.failure_handler(
#     997         e, traceback_exception, start_time, end_time
#     998     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# --> 999 raise e
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/utils.py:880, in client.<locals>.wrapper(*args, **kwargs)
#     878         print_verbose(f"Error while checking max token limit: {str(e)}")
#     879 # MODEL CALL
# --> 880 result = original_function(*args, **kwargs)
#     881 end_time = datetime.datetime.now()
#     882 if "stream" in kwargs and kwargs["stream"] is True:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/main.py:2951, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    2948     return response
#    2949 except Exception as e:
#    2950     ## Map to OpenAI Exception
# -> 2951     raise exception_type(
#    2952         model=model,
#    2953         custom_llm_provider=custom_llm_provider,
#    2954         original_exception=e,
#    2955         completion_kwargs=args,
#    2956         extra_kwargs=kwargs,
#    2957     )
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2148, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2146 if exception_mapping_worked:
#    2147     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2148     raise e
#    2149 else:
#    2150     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File /data/anaconda3/envs/archer_crew/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:314, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     309 elif (
#     310     "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     311     in error_str
#     312 ):
#     313     exception_mapping_worked = True
# --> 314     raise AuthenticationError(
#     315         message=f"AuthenticationError: {exception_provider} - {message}",
#     316         llm_provider=custom_llm_provider,
#     317         model=model,
#     318         response=getattr(original_exception, "response", None),
#     319         litellm_debug_info=extra_information,
#     320     )
#     321 elif "Mistral API raised a streaming error" in error_str:
#     322     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
